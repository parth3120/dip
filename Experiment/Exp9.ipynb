# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Example 1

# %%
import math
x = ['A','B', 'C', 'D', 'E', 'F']
freq = [40,30,10,10,6,4]

class Node:
    def __init__(self):
        self.left = None
        self.right = None
        self.parent = None
        self.nodes = []

freq_node = {}
for i in range(len(x)):
    n = Node()
    n.nodes.append(x[i])
    freq_node[n] = [freq[i],0]


def get_smallest():
    sorted_dict = sorted(freq_node.items(), key=lambda x: (x[1][0], -x[1][1]))

    return sorted_dict[:2]

while len(freq_node)!=1:
    ns1, ns2 = get_smallest()
    n1 = list(ns1)[0]
    n2 = list(ns2)[0]
    v1 = list(ns1)[1][0]
    v2 = list(ns2)[1][0]
    n = Node()
    n.left = n1
    n.right = n2
    n1.parent = n
    n2.parent = n
    n.nodes.extend(n1.nodes)
    n.nodes.extend(n2.nodes)
    del freq_node[n1]
    del freq_node[n2]
    freq_node[n] = [v1+v2, len(n.nodes)]
huffman_codes = {}
for char in x:
    code = ""
    temp = n
    while temp.left or temp.right:
        if char in temp.left.nodes:
            code += "1"

            temp = temp.left
        else:

            temp = temp.right
            code += "0"
    huffman_codes[char] = code
    print(char, "->", code)


def calculate_metrics(freq, huffman_codes):
    total = sum(freq)
    prob = [round(f/total,2) for f in freq]
    len_codes = [len(code) for code in huffman_codes.values()]
    Lavg = 0
    for i in range(len(prob)):
        Lavg += prob[i]*len_codes[i]
    print("--------------------")
    print("Average CodeWord Length: ", Lavg)

    entropy = 0
    for p in prob:
        entropy -= p*math.log2(p)
    print("Entropy: ", entropy)
    print("Efficiency: ", entropy*100/Lavg, "%")
    print("Redundancy:", 1-entropy/Lavg)
# Out:
# A -> 1
# B -> 00
# C -> 0100
# D -> 011
# E -> 01010
# F -> 01011

# %%
calculate_metrics(freq, huffman_codes)
# Out:
# --------------------
# Average CodeWord Length:  2.2
# Entropy:  2.156602958932124
# Efficiency:  98.02740722418744 %
# Redundancy: 0.01972592775812565

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Example 2

# %%
freq
# Out:
# {4: 12, 2: 8, 7: 8, 5: 8, 6: 9, 0: 5, 1: 5, 3: 9}

# %%
import numpy as np
np.random.seed(0)
img = np.random.randint(0, 8, size=(8, 8), dtype=np.uint8)
freq = {}
for r_row in range(img.shape[0]):
    for c_col in range(img.shape[1]):
        r = img[r_row][c_col]
        if r in freq:
            freq[r] += 1
        else:
            freq[r] = 1
pixel = list(freq.keys())
freq = list(freq.values())

# %%
import math
x = pixel
freq = freq

class Node:
    def __init__(self):
        self.left = None
        self.right = None
        self.parent = None
        self.nodes = []

freq_node = {}
for i in range(len(x)):
    n = Node()
    n.nodes.append(x[i])
    freq_node[n] = [freq[i],0]


def get_smallest():
    sorted_dict = sorted(freq_node.items(), key=lambda x: (x[1][0], -x[1][1]))

    return sorted_dict[:2]

while len(freq_node)!=1:
    ns1, ns2 = get_smallest()
    n1 = list(ns1)[0]
    n2 = list(ns2)[0]
    v1 = list(ns1)[1][0]
    v2 = list(ns2)[1][0]
    n = Node()
    n.left = n1
    n.right = n2
    n1.parent = n
    n2.parent = n
    n.nodes.extend(n1.nodes)
    n.nodes.extend(n2.nodes)
    del freq_node[n1]
    del freq_node[n2]
    freq_node[n] = [v1+v2, len(n.nodes)]
huffman_codes = {}
for char in x:
    code = ""
    temp = n
    while temp.left or temp.right:
        if char in temp.left.nodes:
            code += "1"

            temp = temp.left
        else:

            temp = temp.right
            code += "0"
    huffman_codes[char] = code
    print(char, "->", code)


def calculate_metrics(freq, huffman_codes):
    total = sum(freq)
    prob = [round(f/total,2) for f in freq]
    len_codes = [len(code) for code in huffman_codes.values()]
    Lavg = 0
    for i in range(len(prob)):
        Lavg += prob[i]*len_codes[i]
    print("--------------------")
    print("Average CodeWord Length: ", Lavg)

    entropy = 0
    for p in prob:
        entropy -= p*math.log2(p)
    print("Entropy: ", entropy)
    print("Efficiency: ", entropy*100/Lavg, "%")
    print("Redundancy:", 1-entropy/Lavg)
# Out:
# 4 -> 11
# 2 -> 101
# 7 -> 100
# 5 -> 011
# 6 -> 010
# 0 -> 0001
# 1 -> 0000
# 3 -> 001

# %%
calculate_metrics(freq, huffman_codes)
# Out:
# --------------------
# Average CodeWord Length:  2.9399999999999995
# Entropy:  2.9336655218869514
# Efficiency:  99.78454156078068 %
# Redundancy: 0.0021545843921931818
