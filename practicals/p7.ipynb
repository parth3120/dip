# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('/content/drive/MyDrive/dip_Images/Original-cameraman-image.png', cv2.IMREAD_GRAYSCALE)

roberts_x = np.array([[1, 0], [0, -1]])
roberts_y = np.array([[0, 1], [-1, 0]])

roberts_x_image = cv2.filter2D(image, -1, roberts_x).astype(np.float32)
roberts_y_image = cv2.filter2D(image, -1, roberts_y).astype(np.float32)

roberts_combined_image = cv2.magnitude(roberts_x_image, roberts_y_image)

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(roberts_x_image, cmap='gray')
plt.title('Robert Operator X')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(roberts_y_image, cmap='gray')
plt.title('Robert Operator Y')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(roberts_combined_image, cmap='gray')
plt.title('Robert Operator Combined')
plt.axis('off')

plt.show()

# %%
sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])

sobel_x_image = cv2.filter2D(image, -1, sobel_x).astype(np.float32)
sobel_y_image = cv2.filter2D(image, -1, sobel_y).astype(np.float32)

sobel_combined_image = cv2.magnitude(sobel_x_image, sobel_y_image)

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(sobel_x_image, cmap='gray')
plt.title('Sobel Operator X')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(sobel_y_image, cmap='gray')
plt.title('Sobel Operator Y')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(sobel_combined_image, cmap='gray')
plt.title('Sobel Operator Combined')
plt.axis('off')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
prewitt_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
prewitt_y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]])

prewitt_x_image = cv2.filter2D(image, -1, prewitt_x).astype(np.float32)
prewitt_y_image = cv2.filter2D(image, -1, prewitt_y).astype(np.float32)

prewitt_combined_image = cv2.magnitude(prewitt_x_image, prewitt_y_image)

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(prewitt_x_image, cmap='gray')
plt.title('Prewitt Operator X')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(prewitt_y_image, cmap='gray')
plt.title('Prewitt Operator Y')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(prewitt_combined_image, cmap='gray')
plt.title('Prewitt Operator Combined')
plt.axis('off')

plt.show()
